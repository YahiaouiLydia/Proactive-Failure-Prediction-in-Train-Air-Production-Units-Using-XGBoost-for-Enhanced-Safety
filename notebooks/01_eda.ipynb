# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r"C:\Users\maite\OneDrive\Bureau\Contributions\Conference\IEEE IWCMC 2025 XGBoost-based faillures prediction in APU\data\raw\MetroPT3(CompressorDatase).csv")
data['timestamp'] = pd.to_datetime(data['timestamp'])
print(data.describe())
data.drop(columns=['Unnamed: 0']).hist(figsize=(12, 10))
plt.tight_layout()
# plt.savefig('../eda_histograms.png')
plt.show()
# Out:
#          Unnamed: 0                      timestamp           TP2  \
# count  1.516948e+07                       15169480  1.516948e+07
# mean   7.584740e+06  2020-05-16 22:58:42.240492032  1.367726e+00
# min    0.000000e+00            2020-02-01 00:00:00 -3.400000e-02
# 25%    3.792370e+06  2020-03-23 05:05:06.750000128 -1.400000e-02
# 50%    7.584740e+06     2020-05-17 08:07:10.500000 -1.200000e-02
# 75%    1.137711e+07  2020-07-10 03:07:34.249999872 -1.000000e-02
# max    1.516948e+07            2020-09-01 03:59:59  1.067600e+01
# std    4.379052e+06                            NaN  3.250931e+00
#
#                 TP3            H1   DV_pressure    Reservoirs  \
# count  1.516948e+07  1.516948e+07  1.516948e+07  1.516948e+07
# mean   8.984597e+00  7.568100e+00  5.593404e-02  8.985220e+00
# min    6.900000e-01 -3.600000e-02 -3.400000e-02  6.700000e-01
# 25%    8.492000e+00  8.254000e+00 -2.200000e-02  8.494000e+00
# 50%    8.960000e+00  8.784000e+00 -2.000000e-02  8.960000e+00
# ...
