# %%
import sys
import os

# Ajoute le dossier racine (ml_project/) au chemin de recherche
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import pandas as pd
from src.data import data_preprocessing  

# Use your exact file path
X_train, X_test, y_train, y_test = data_preprocessing()

pd.DataFrame(X_train).to_csv("../data/processed/X_train.csv", index=False)
pd.DataFrame(X_test).to_csv("../data/processed/X_test.csv", index=False)
pd.Series(y_train).to_csv("../data/processed/y_train.csv", index=False)
pd.Series(y_test).to_csv("../data/processed/y_test.csv", index=False)
# Out:
# Relevant features: Index(['pre_failure', 'DV_pressure', 'Oil_temperature'], dtype='object')
# Selected features: ['TP2', 'TP3', 'DV_pressure', 'Oil_temperature', 'LPS', 'Pressure_switch', 'Oil_level', 'Caudal_impulses', 'DV_pressure_avg_3day', 'Oil_temperature_avg_3day']
